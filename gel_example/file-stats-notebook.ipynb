# %% [markdown]
# # Storage details for Genomics England chr2 dataset
#
# This is a summary of the chr2-stats notebook,and using the data from ICF and Zarr "inspect" commands stored in corresponding CSVs.

# %% [markdown]
# ## VCFs
#
# The VCF data for chromosome 2 for the aggV2 dataset is split across 106 chunks, using a total of 12.81 TiB of storage.

# %% [markdown]
# ## Intermediate columnar format
#
# We converted the full VCF to ICF using vcf2zarr's distributed explode commands.
# We split the job into 14605 partitions, with a 20.7min average run time.
#
# The storage used by each field is shown below. Total size is 9.94 TiB.

# %%
import pandas as pd
import humanfriendly
import numpy as np

def parse_size(values):
    size = np.zeros(values.shape, dtype=int)
    for j, val in enumerate(values):
        size[j] = humanfriendly.parse_size(val)
    return size

df_icf = pd.read_csv("chr2_if_inspect.csv")
df_icf["compressed_bytes"] = parse_size(df_icf.compressed.values)
df_icf.sort_values("compressed_bytes", ascending=False)
# Out:
#                        name     type  chunks        size  compressed  max_n  \
# 10                FORMAT/AD  Integer  561755   34.08 TiB    3.57 TiB      2
# 13                FORMAT/GQ  Integer  285891   17.04 TiB    2.62 TiB      1
# 8                 FORMAT/DP  Integer  285891   17.04 TiB    2.23 TiB      1
# 9                FORMAT/DPF  Integer  285891   17.04 TiB    1.05 TiB      1
# 15                FORMAT/PL  Integer  838874   51.11 TiB  238.94 GiB      3
# 7                 FORMAT/GT  Integer  426102   25.56 TiB  149.29 GiB      3
# 17               FORMAT/GQX  Integer  285891   17.04 TiB   59.52 GiB      1
# 14                FORMAT/FT   String  561755   34.08 TiB    33.2 GiB      1
# 2                      QUAL    Float   14763    6.25 GiB  116.39 MiB      1
# 18    INFO/OLD_MULTIALLELIC   String   14763     7.1 GiB   86.08 MiB      1
# 33                  INFO/AC  Integer   14763    6.25 GiB    70.2 MiB      1
# 35              INFO/AC_Het  Integer   14763    6.25 GiB    69.8 MiB      1
# 6                       ALT   String   14763    6.61 GiB   63.78 MiB      1
# 1                       POS  Integer   14763    6.25 GiB   62.72 MiB      1
# 5                       REF   String   14763    6.25 GiB   62.59 MiB      1
# 32                  INFO/AN  Integer   14763    6.25 GiB      53 MiB      1
# 25             INFO/ABratio    Float   14763    6.23 GiB   32.15 MiB      1
# 22            INFO/medianGQ    Float   14763    6.25 GiB   31.22 MiB      1
# 26          INFO/MendelSite    Float   14763    6.25 GiB   30.47 MiB      1
# 24     INFO/completeGTRatio    Float   14763    6.25 GiB   22.75 MiB      1
# 30            INFO/phwe_eur    Float   14763    6.25 GiB   22.65 MiB      1
# 27            INFO/phwe_afr    Float   14763    6.25 GiB   21.55 MiB      1
# 21  INFO/medianDepthNonMiss    Float   14763    6.25 GiB   20.66 MiB      1
# 20      INFO/medianDepthAll    Float   14763    6.25 GiB   20.39 MiB      1
# 31            INFO/phwe_sas    Float   14763    6.25 GiB   19.01 MiB      1
# 34              INFO/AC_Hom  Integer   14763    6.25 GiB   18.07 MiB      1
# 4                   FILTERS   String   14763    7.73 GiB    15.7 MiB      1
# 23         INFO/missingness    Float   14763    6.25 GiB   15.32 MiB      1
# 29            INFO/phwe_eas    Float   14763    6.25 GiB   12.93 MiB      1
# 36             INFO/AC_Hemi  Integer   14763    6.25 GiB    4.24 MiB      1
# 0                     CHROM   String   14763    6.25 GiB    4.04 MiB      1
# 19         INFO/OLD_CLUMPED   String   14763  917.52 MiB     1.1 MiB      1
# 28            INFO/phwe_amr    Float   14763  913.71 MiB  864.92 KiB      0
# 16                FORMAT/PS  Integer   14763  913.71 MiB  864.92 KiB      0
# 12               FORMAT/ADR  Integer   14763  913.71 MiB  864.92 KiB      0
# 11               FORMAT/ADF  Integer   14763  913.71 MiB  864.92 KiB      0
# 3                        ID   String   14763  913.71 MiB  864.92 KiB      0
#
#     min_val       max_val  compressed_bytes
# 10      0.0  1.000000e+04     3925256511160
# 13      0.0  3.100000e+03     2880720464773
# 8       0.0  1.000000e+04     2451910929940
# 9       0.0  8.300000e+03     1154487209164
# 15      0.0  3.000000e+03      256559871426
# 7      -2.0  1.000000e+00      160298916904
# 17      0.0  3.100000e+03       63909113364
# 14      NaN           NaN       35648228556
# 2       0.0  6.100000e+06         122043760
# 18      NaN           NaN          90261422
# 33      0.0  1.600000e+05          73610035
# 35      0.0  7.800000e+04          73190604
# 6       NaN           NaN          66878177
# 1   10000.0  2.400000e+08          65766686
# 5       NaN           NaN          65630371
# 32      0.0  1.600000e+05          55574528
# 25      0.0  1.000000e+00          33711718
# 22      0.0  9.900000e+01          32736542
# 26      0.0  2.300000e+03          31950110
# 24      0.0  1.000000e+00          23855104
# 30      0.0  1.000000e+00          23750246
# 27      0.0  9.800000e-01          22596812
# 21      0.0  9.900000e+01          21663580
# 20      0.0  1.900000e+03          21380464
# 31      0.0  9.900000e-01          19933429
# 34      0.0  1.600000e+05          18947768
# 4       NaN           NaN          16462643
# 23      0.0  1.000000e+00          16064184
# 29      0.0  9.600000e-01          13558087
# 36      0.0  5.800000e+04           4445962
# 0       NaN           NaN           4236247
# 19      NaN           NaN           1153433
# 28      NaN           NaN            885678
# 16      NaN           NaN            885678
# 12      NaN           NaN            885678
# 11      NaN           NaN            885678
# 3       NaN           NaN            885678

# %%
humanfriendly.format_size(df_icf.compressed_bytes.sum(), binary=True)
# Out:
# '9.94 TiB'

# %% [markdown]
# How many chunk files?

# %%
df_icf.chunks.sum()
# Out:
# 3960177

# %% [markdown]
# ## VCF Zarr
#
# We converted the ICF data to Zarr using vcf2zarr distributed encode commands.
# We split the job into 5989 partitions with an 18.6min average run time.
#
# It uses a total of 2.54 TiB of storage over 8294982 files and directories.
#
# This is a compression of 5X over the VCF.

# %%
12.81 / 2.54
# Out:
# 5.043307086614173

# %%
df_zarr = pd.read_csv("chr2_zarr_inspect.csv")
df_zarr["stored_bytes"] = parse_size(df_zarr.stored.values)
df_zarr.sort_values("stored_bytes", ascending=False, inplace=True)
df_zarr
# Out:
#                            name    dtype      stored        size     ratio  \
# 0                      /call_AD    int16  658.44 GiB   17.03 TiB     26.00
# 1                      /call_GQ    int16  654.45 GiB    8.52 TiB     13.00
# 2                      /call_DP    int16  570.03 GiB    8.52 TiB     15.00
# 3                     /call_DPF    int16  447.09 GiB    8.52 TiB     20.00
# 4                      /call_PL    int16  162.56 GiB   25.55 TiB    160.00
# 5                     /call_GQX    int16   40.99 GiB    8.52 TiB    210.00
# 6                      /call_FT   object   25.04 GiB   34.07 TiB   1400.00
# 7                /call_genotype     int8   21.46 GiB    8.52 TiB    410.00
# 8           /call_genotype_mask     bool   12.78 GiB    8.52 TiB    680.00
# 9         /call_genotype_phased     bool    2.35 GiB    4.26 TiB   1900.00
# 12                     /call_PS     int8  383.38 MiB    4.26 TiB  12000.00
# 11                    /call_ADF     int8  383.38 MiB    4.26 TiB  12000.00
# 10                    /call_ADR     int8  383.38 MiB    4.26 TiB  12000.00
# 13            /variant_position    int32   111.6 MiB  228.43 MiB      2.00
# 14             /variant_quality  float32    87.4 MiB  228.43 MiB      2.60
# 15              /variant_allele   object   69.33 MiB  913.71 MiB     13.00
# 16    /variant_OLD_MULTIALLELIC   object   55.88 MiB  456.86 MiB      8.20
# 17                  /variant_AN    int32   47.32 MiB  228.43 MiB      4.80
# 18                  /variant_AC    int32      47 MiB  228.43 MiB      4.90
# 19              /variant_AC_Het    int32   46.62 MiB  228.43 MiB      4.90
# 20             /variant_ABratio  float32   20.23 MiB  228.43 MiB     11.00
# 21          /variant_MendelSite  float32   20.09 MiB  228.43 MiB     11.00
# 22            /variant_medianGQ  float32   19.16 MiB  228.43 MiB     12.00
# 23     /variant_completeGTRatio  float32   14.98 MiB  228.43 MiB     15.00
# 24            /variant_phwe_eur  float32   14.46 MiB  228.43 MiB     16.00
# 25            /variant_phwe_afr  float32   13.37 MiB  228.43 MiB     17.00
# 26  /variant_medianDepthNonMiss  float32   12.17 MiB  228.43 MiB     19.00
# 27      /variant_medianDepthAll  float32   11.99 MiB  228.43 MiB     19.00
# 28            /variant_phwe_sas  float32   11.59 MiB  228.43 MiB     20.00
# 29              /variant_AC_Hom    int32   11.12 MiB  228.43 MiB     21.00
# 30         /variant_missingness  float32     9.3 MiB  228.43 MiB     25.00
# 31            /variant_phwe_eas  float32    7.12 MiB  228.43 MiB     32.00
# 32              /variant_filter     bool    6.42 MiB    3.57 GiB    570.00
# 33             /variant_AC_Hemi    int32  849.43 KiB  228.43 MiB    280.00
# 34    /variant_composite_filter     bool  433.38 KiB   57.11 MiB    130.00
# 35         /variant_OLD_CLUMPED   object  384.18 KiB  456.86 MiB   1200.00
# 36                  /variant_id   object  298.76 KiB  456.86 MiB   1600.00
# 37            /variant_phwe_amr  float32  269.52 KiB  228.43 MiB    870.00
# 38             /variant_id_mask     bool  269.46 KiB   57.11 MiB    220.00
# 39                   /sample_id   object  268.12 KiB   610.9 KiB      2.30
# 40              /variant_contig    int16  257.77 KiB  114.21 MiB    450.00
# 41               /contig_length    int64    3.79 KiB   20.16 KiB      5.30
# 42                   /contig_id   object     2.3 KiB   20.16 KiB      8.80
# 43                   /filter_id   object   808 bytes   512 bytes      0.63
#
#     nchunks   chunk_size avg_chunk_stored                 shape  \
# 0    473131    37.75 MiB         1.43 MiB  (59880903, 78195, 2)
# 1    473131    18.88 MiB         1.42 MiB     (59880903, 78195)
# 2    473131    18.88 MiB         1.23 MiB     (59880903, 78195)
# 3    473131    18.88 MiB       990.86 KiB     (59880903, 78195)
# 4    473131    56.63 MiB       360.27 KiB  (59880903, 78195, 3)
# 5    473131    18.88 MiB        90.84 KiB     (59880903, 78195)
# 6    473131    75.51 MiB         55.5 KiB     (59880903, 78195)
# 7    473131    18.88 MiB        47.57 KiB  (59880903, 78195, 2)
# 8    473131    18.88 MiB        28.32 KiB  (59880903, 78195, 2)
# 9    473131     9.44 MiB          5.2 KiB     (59880903, 78195)
# 12   473131     9.44 MiB        849 bytes     (59880903, 78195)
# 11   473131     9.44 MiB        849 bytes     (59880903, 78195)
# 10   473131     9.44 MiB        849 bytes     (59880903, 78195)
# 13     5989    39.06 KiB        19.08 KiB           (59880903,)
# 14     5989    39.06 KiB        14.94 KiB           (59880903,)
# 15     5989   156.23 KiB        11.85 KiB         (59880903, 2)
# 16     5989    78.11 KiB         9.55 KiB           (59880903,)
# 17     5989    39.06 KiB         8.09 KiB           (59880903,)
# 18     5989    39.06 KiB         8.04 KiB           (59880903,)
# 19     5989    39.06 KiB         7.97 KiB           (59880903,)
# 20     5989    39.06 KiB         3.46 KiB           (59880903,)
# 21     5989    39.06 KiB         3.43 KiB           (59880903,)
# 22     5989    39.06 KiB         3.28 KiB           (59880903,)
# 23     5989    39.06 KiB         2.56 KiB           (59880903,)
# 24     5989    39.06 KiB         2.47 KiB           (59880903,)
# 25     5989    39.06 KiB         2.29 KiB           (59880903,)
# 26     5989    39.06 KiB         2.08 KiB           (59880903,)
# 27     5989    39.06 KiB         2.05 KiB           (59880903,)
# 28     5989    39.06 KiB         1.98 KiB           (59880903,)
# 29     5989    39.06 KiB          1.9 KiB           (59880903,)
# 30     5989    39.06 KiB         1.59 KiB           (59880903,)
# 31     5989    39.06 KiB         1.22 KiB           (59880903,)
# 32     5989   624.91 KiB          1.1 KiB        (59880903, 64)
# 33     5989    39.06 KiB        145 bytes           (59880903,)
# 34     5989     9.76 KiB         74 bytes           (59880903,)
# 35     5989    78.11 KiB         65 bytes           (59880903,)
# 36     5989    78.11 KiB         51 bytes           (59880903,)
# 37     5989    39.06 KiB         46 bytes           (59880903,)
# 38     5989     9.76 KiB         46 bytes           (59880903,)
# 39       79     7.73 KiB         3.39 KiB              (78195,)
# 40     5989    19.53 KiB         44 bytes           (59880903,)
# 41        1    20.16 KiB         3.79 KiB               (2580,)
# 42        1    20.16 KiB          2.3 KiB               (2580,)
# 43        1  512.0 bytes        808 bytes                 (64,)
#
#          chunk_shape                                         compressor  \
# 0   (10000, 1000, 2)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 1      (10000, 1000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 2      (10000, 1000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 3      (10000, 1000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 4   (10000, 1000, 3)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 5      (10000, 1000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 6      (10000, 1000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 7   (10000, 1000, 2)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 8   (10000, 1000, 2)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 9      (10000, 1000)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 12     (10000, 1000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 11     (10000, 1000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 10     (10000, 1000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 13          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 14          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 15        (10000, 2)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 16          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 17          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 18          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 19          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 20          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 21          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 22          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 23          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 24          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 25          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 26          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 27          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 28          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 29          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 30          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 31          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 32       (10000, 64)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 33          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 34          (10000,)  Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, ...
# 35          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 36          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 37          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 38          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 39           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
# 40          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 41           (2580,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
# 42           (2580,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
# 43             (64,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
#
#          filters  stored_bytes
# 0            NaN  706994566594
# 1            NaN  702710336716
# 2            NaN  612065051934
# 3            NaN  480059232092
# 4            NaN  174547470909
# 5            NaN   44012677365
# 6   [VLenUTF8()]   26886495272
# 7            NaN   23042499543
# 8            NaN   13722420510
# 9            NaN    2523293286
# 12           NaN     402003066
# 11           NaN     402003066
# 10           NaN     402003066
# 13           NaN     117021081
# 14           NaN      91645542
# 15  [VLenUTF8()]      72697774
# 16  [VLenUTF8()]      58594426
# 17           NaN      49618616
# 18           NaN      49283072
# 19           NaN      48884613
# 20           NaN      21212692
# 21           NaN      21065891
# 22           NaN      20090716
# 23           NaN      15707668
# 24           NaN      15162408
# 25           NaN      14019461
# 26           NaN      12761169
# 27           NaN      12572426
# 28           NaN      12152995
# 29           NaN      11660165
# 30           NaN       9751756
# 31           NaN       7465861
# 32           NaN       6731857
# 33           NaN        869816
# 34           NaN        443781
# 35  [VLenUTF8()]        393400
# 36  [VLenUTF8()]        305930
# 37           NaN        275988
# 38           NaN        275927
# 39  [VLenUTF8()]        274554
# 40           NaN        263956
# 41           NaN          3880
# 42  [VLenUTF8()]          2355
# 43  [VLenUTF8()]           808

# %%
total = df_zarr.stored_bytes.sum()

humanfriendly.format_size(total, binary=True)
# Out:
# '2.54 TiB'

# %%
df_zarr.nchunks.sum()
# Out:
# 6312488

# %% [markdown]
# How much of the overall storage is consumed by the top 4 fields?

# %%
df_zarr.head(4).stored_bytes.sum() / total
# Out:
# 0.8972142320632752

# %%
df_display_table = pd.DataFrame({
    "Field":df_zarr.name,
    "type": df_zarr.dtype,
    "storage":df_zarr.stored,
    "compress": df_zarr.ratio,
    "percentage": df_zarr.stored_bytes / total})
df_display_table.sort_values("percentage", ascending=False, inplace=True)
df_display_table["percentage"] = df_display_table["percentage"].map('{:.2%}'.format)
df_display_table["compress"] = df_display_table["compress"].map('{:.1f}'.format)
df_display_table
# Out:
#                           Field     type     storage compress percentage
# 0                      /call_AD    int16  658.44 GiB     26.0     25.35%
# 1                      /call_GQ    int16  654.45 GiB     13.0     25.20%
# 2                      /call_DP    int16  570.03 GiB     15.0     21.95%
# 3                     /call_DPF    int16  447.09 GiB     20.0     17.22%
# 4                      /call_PL    int16  162.56 GiB    160.0      6.26%
# 5                     /call_GQX    int16   40.99 GiB    210.0      1.58%
# 6                      /call_FT   object   25.04 GiB   1400.0      0.96%
# 7                /call_genotype     int8   21.46 GiB    410.0      0.83%
# 8           /call_genotype_mask     bool   12.78 GiB    680.0      0.49%
# 9         /call_genotype_phased     bool    2.35 GiB   1900.0      0.09%
# 12                     /call_PS     int8  383.38 MiB  12000.0      0.01%
# 11                    /call_ADF     int8  383.38 MiB  12000.0      0.01%
# 10                    /call_ADR     int8  383.38 MiB  12000.0      0.01%
# 13            /variant_position    int32   111.6 MiB      2.0      0.00%
# 14             /variant_quality  float32    87.4 MiB      2.6      0.00%
# 15              /variant_allele   object   69.33 MiB     13.0      0.00%
# 16    /variant_OLD_MULTIALLELIC   object   55.88 MiB      8.2      0.00%
# 17                  /variant_AN    int32   47.32 MiB      4.8      0.00%
# 18                  /variant_AC    int32      47 MiB      4.9      0.00%
# 19              /variant_AC_Het    int32   46.62 MiB      4.9      0.00%
# 20             /variant_ABratio  float32   20.23 MiB     11.0      0.00%
# 21          /variant_MendelSite  float32   20.09 MiB     11.0      0.00%
# 22            /variant_medianGQ  float32   19.16 MiB     12.0      0.00%
# 23     /variant_completeGTRatio  float32   14.98 MiB     15.0      0.00%
# 24            /variant_phwe_eur  float32   14.46 MiB     16.0      0.00%
# 25            /variant_phwe_afr  float32   13.37 MiB     17.0      0.00%
# 26  /variant_medianDepthNonMiss  float32   12.17 MiB     19.0      0.00%
# 27      /variant_medianDepthAll  float32   11.99 MiB     19.0      0.00%
# 28            /variant_phwe_sas  float32   11.59 MiB     20.0      0.00%
# 29              /variant_AC_Hom    int32   11.12 MiB     21.0      0.00%
# 30         /variant_missingness  float32     9.3 MiB     25.0      0.00%
# 31            /variant_phwe_eas  float32    7.12 MiB     32.0      0.00%
# 32              /variant_filter     bool    6.42 MiB    570.0      0.00%
# 33             /variant_AC_Hemi    int32  849.43 KiB    280.0      0.00%
# 34    /variant_composite_filter     bool  433.38 KiB    130.0      0.00%
# 35         /variant_OLD_CLUMPED   object  384.18 KiB   1200.0      0.00%
# 36                  /variant_id   object  298.76 KiB   1600.0      0.00%
# 37            /variant_phwe_amr  float32  269.52 KiB    870.0      0.00%
# 38             /variant_id_mask     bool  269.46 KiB    220.0      0.00%
# 39                   /sample_id   object  268.12 KiB      2.3      0.00%
# 40              /variant_contig    int16  257.77 KiB    450.0      0.00%
# 41               /contig_length    int64    3.79 KiB      5.3      0.00%
# 42                   /contig_id   object     2.3 KiB      8.8      0.00%
# 43                   /filter_id   object   808 bytes      0.6      0.00%

# %% [markdown]
# Output the (rough) table data for the manuscript:

# %%
print(df_display_table.to_latex(index=False))
# Out:
# \begin{tabular}{lllll}
# \toprule
# Field & type & storage & compress & percentage \\
# \midrule
# /call_AD & int16 & 658.44 GiB & 26.0 & 25.35% \\
# /call_GQ & int16 & 654.45 GiB & 13.0 & 25.20% \\
# /call_DP & int16 & 570.03 GiB & 15.0 & 21.95% \\
# /call_DPF & int16 & 447.09 GiB & 20.0 & 17.22% \\
# /call_PL & int16 & 162.56 GiB & 160.0 & 6.26% \\
# /call_GQX & int16 & 40.99 GiB & 210.0 & 1.58% \\
# /call_FT & object & 25.04 GiB & 1400.0 & 0.96% \\
# /call_genotype & int8 & 21.46 GiB & 410.0 & 0.83% \\
# /call_genotype_mask & bool & 12.78 GiB & 680.0 & 0.49% \\
# /call_genotype_phased & bool & 2.35 GiB & 1900.0 & 0.09% \\
# /call_PS & int8 & 383.38 MiB & 12000.0 & 0.01% \\
# /call_ADF & int8 & 383.38 MiB & 12000.0 & 0.01% \\
# /call_ADR & int8 & 383.38 MiB & 12000.0 & 0.01% \\
# /variant_position & int32 & 111.6 MiB & 2.0 & 0.00% \\
# /variant_quality & float32 & 87.4 MiB & 2.6 & 0.00% \\
# /variant_allele & object & 69.33 MiB & 13.0 & 0.00% \\
# /variant_OLD_MULTIALLELIC & object & 55.88 MiB & 8.2 & 0.00% \\
# /variant_AN & int32 & 47.32 MiB & 4.8 & 0.00% \\
# /variant_AC & int32 & 47 MiB & 4.9 & 0.00% \\
# /variant_AC_Het & int32 & 46.62 MiB & 4.9 & 0.00% \\
# /variant_ABratio & float32 & 20.23 MiB & 11.0 & 0.00% \\
# /variant_MendelSite & float32 & 20.09 MiB & 11.0 & 0.00% \\
# /variant_medianGQ & float32 & 19.16 MiB & 12.0 & 0.00% \\
# /variant_completeGTRatio & float32 & 14.98 MiB & 15.0 & 0.00% \\
# /variant_phwe_eur & float32 & 14.46 MiB & 16.0 & 0.00% \\
# /variant_phwe_afr & float32 & 13.37 MiB & 17.0 & 0.00% \\
# /variant_medianDepthNonMiss & float32 & 12.17 MiB & 19.0 & 0.00% \\
# /variant_medianDepthAll & float32 & 11.99 MiB & 19.0 & 0.00% \\
# /variant_phwe_sas & float32 & 11.59 MiB & 20.0 & 0.00% \\
# /variant_AC_Hom & int32 & 11.12 MiB & 21.0 & 0.00% \\
# /variant_missingness & float32 & 9.3 MiB & 25.0 & 0.00% \\
# /variant_phwe_eas & float32 & 7.12 MiB & 32.0 & 0.00% \\
# /variant_filter & bool & 6.42 MiB & 570.0 & 0.00% \\
# /variant_AC_Hemi & int32 & 849.43 KiB & 280.0 & 0.00% \\
# /variant_composite_filter & bool & 433.38 KiB & 130.0 & 0.00% \\
# /variant_OLD_CLUMPED & object & 384.18 KiB & 1200.0 & 0.00% \\
# /variant_id & object & 298.76 KiB & 1600.0 & 0.00% \\
# /variant_phwe_amr & float32 & 269.52 KiB & 870.0 & 0.00% \\
# /variant_id_mask & bool & 269.46 KiB & 220.0 & 0.00% \\
# /sample_id & object & 268.12 KiB & 2.3 & 0.00% \\
# /variant_contig & int16 & 257.77 KiB & 450.0 & 0.00% \\
# /contig_length & int64 & 3.79 KiB & 5.3 & 0.00% \\
# /contig_id & object & 2.3 KiB & 8.8 & 0.00% \\
# /filter_id & object & 808 bytes & 0.6 & 0.00% \\
# \bottomrule
# \end{tabular}
