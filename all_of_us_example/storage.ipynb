# %%
import os
import pandas as pd
import humanfriendly
import numpy as np
from pathlib import Path

# %%
def parse_size(values):
    size = np.zeros(values.shape, dtype=int)
    for j, val in enumerate(values):
        size[j] = humanfriendly.parse_size(val)
    return size

# %%
fn = "all_of_us_example/zarr_inspect.csv"
df_zarr = pd.read_csv(fn)
df_zarr["stored_bytes"] = parse_size(df_zarr.stored.values)
df_zarr.sort_values("stored_bytes", ascending=False, inplace=True)
df_zarr
# Out:
#                      name    dtype      stored        size     ratio  nchunks  \
# 0                /call_GQ     int8    1.89 GiB  163.47 GiB    87.000    17900
# 1          /call_genotype     int8  914.22 MiB  326.93 GiB   370.000    17900
# 2               /call_RGQ    int16  729.57 MiB  326.93 GiB   460.000    17900
# 3     /call_genotype_mask     bool  606.02 MiB  326.93 GiB   550.000    17900
# 4   /call_genotype_phased     bool   17.17 MiB  163.47 GiB  9700.000    17900
# 5         /variant_allele   object    4.74 MiB  518.41 MiB   110.000      716
# 6         /variant_filter     bool    2.87 MiB    2.73 MiB     0.950      716
# 7             /variant_AN    int32  908.75 KiB    2.73 MiB     3.100      716
# 8       /variant_position    int32  810.77 KiB    2.73 MiB     3.400      716
# 9              /sample_id   object  357.15 KiB    1.87 MiB     5.400       25
# 10        /variant_length    int16   152.4 KiB    1.36 MiB     9.200      716
# 11            /variant_id   object   56.18 KiB    5.46 MiB    99.000      716
# 12       /variant_quality  float32   51.92 KiB    2.73 MiB    54.000      716
# 13       /variant_id_mask     bool   51.89 KiB  698.49 KiB    13.000      716
# 14        /variant_contig    int16    50.6 KiB    1.36 MiB    28.000      716
# 15          /region_index    int32   13.93 KiB   16.78 KiB     1.200        1
# 16         /contig_length    int64    9.24 KiB    26.3 KiB     2.800        1
# 17             /contig_id   object    8.33 KiB    26.3 KiB     3.200        1
# 18             /filter_id   object    4.48 KiB    32 bytes     0.007        1
#
#                  chunk_size avg_chunk_stored                shape  \
# 0                  9.35 MiB       110.55 KiB     (715256, 245394)
# 1                  18.7 MiB         52.3 KiB  (715256, 245394, 2)
# 2                  18.7 MiB        41.74 KiB     (715256, 245394)
# 3                  18.7 MiB        34.67 KiB  (715256, 245394, 2)
# 4                  9.35 MiB       1006 bytes     (715256, 245394)
# 5                741.42 KiB         6.78 KiB         (715256, 95)
# 6                   3.9 KiB          4.1 KiB          (715256, 4)
# 7                   3.9 KiB         1.27 KiB            (715256,)
# 8                   3.9 KiB         1.13 KiB            (715256,)
# 9                 76.69 KiB        14.29 KiB            (245394,)
# 10                 1.95 KiB        217 bytes            (715256,)
# 11                  7.8 KiB         80 bytes            (715256,)
# 12                  3.9 KiB         74 bytes            (715256,)
# 13  998.9608938547486 bytes         74 bytes            (715256,)
# 14                 1.95 KiB         72 bytes            (715256,)
# 15                16.78 KiB        13.93 KiB             (716, 6)
# 16                 26.3 KiB         9.24 KiB              (3366,)
# 17                 26.3 KiB         8.33 KiB              (3366,)
# 18               32.0 bytes         4.48 KiB                 (4,)
#
#          chunk_shape                                         compressor  \
# 0      (1000, 10000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 1   (1000, 10000, 2)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 2      (1000, 10000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 3   (1000, 10000, 2)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 4      (1000, 10000)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 5         (1000, 95)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 6          (1000, 4)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 7            (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 8            (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 9           (10000,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
# 10           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 11           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 12           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 13           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 14           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 15          (716, 6)  Blosc(cname='zstd', clevel=9, shuffle=NOSHUFFL...
# 16           (3366,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
# 17           (3366,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
# 18              (4,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
#
#          filters  stored_bytes
# 0            NaN    2029372047
# 1            NaN     958629150
# 2            NaN     765009592
# 3            NaN     635458027
# 4            NaN      18004049
# 5   [VLenUTF8()]       4970250
# 6            NaN       3009413
# 7            NaN        930560
# 8            NaN        830228
# 9   [VLenUTF8()]        365721
# 10           NaN        156057
# 11  [VLenUTF8()]         57528
# 12           NaN         53166
# 13           NaN         53135
# 14           NaN         51814
# 15           NaN         14264
# 16           NaN          9461
# 17  [VLenUTF8()]          8529
# 18  [VLenUTF8()]          4587

# %%
total = df_zarr.stored_bytes.sum()

humanfriendly.format_size(total, binary=True)
# Out:
# '4.11 GiB'

# %%
df_zarr.nchunks.sum()
# Out:
# 95973

# %%
df_display_table = pd.DataFrame({
    "Field":df_zarr.name,
    "type": df_zarr.dtype,
    "storage":df_zarr.stored,
    "compress": df_zarr.ratio,
    "percentage": df_zarr.stored_bytes / total})
df_display_table.sort_values("percentage", ascending=False, inplace=True)
df_display_table["percentage"] = df_display_table["percentage"].map('{:.2%}'.format)
df_display_table["compress"] = df_display_table["compress"].map('{:.1f}'.format)
df_display_table
# Out:
#                     Field     type     storage compress percentage
# 0                /call_GQ     int8    1.89 GiB     87.0     45.94%
# 1          /call_genotype     int8  914.22 MiB    370.0     21.70%
# 2               /call_RGQ    int16  729.57 MiB    460.0     17.32%
# 3     /call_genotype_mask     bool  606.02 MiB    550.0     14.39%
# 4   /call_genotype_phased     bool   17.17 MiB   9700.0      0.41%
# 5         /variant_allele   object    4.74 MiB    110.0      0.11%
# 6         /variant_filter     bool    2.87 MiB      0.9      0.07%
# 7             /variant_AN    int32  908.75 KiB      3.1      0.02%
# 8       /variant_position    int32  810.77 KiB      3.4      0.02%
# 9              /sample_id   object  357.15 KiB      5.4      0.01%
# 10        /variant_length    int16   152.4 KiB      9.2      0.00%
# 11            /variant_id   object   56.18 KiB     99.0      0.00%
# 12       /variant_quality  float32   51.92 KiB     54.0      0.00%
# 13       /variant_id_mask     bool   51.89 KiB     13.0      0.00%
# 14        /variant_contig    int16    50.6 KiB     28.0      0.00%
# 15          /region_index    int32   13.93 KiB      1.2      0.00%
# 16         /contig_length    int64    9.24 KiB      2.8      0.00%
# 17             /contig_id   object    8.33 KiB      3.2      0.00%
# 18             /filter_id   object    4.48 KiB      0.0      0.00%

# %%
print(df_display_table.to_latex(index=False))
# Out:
# \begin{tabular}{lllll}
# \toprule
# Field & type & storage & compress & percentage \\
# \midrule
# /call_GQ & int8 & 1.89 GiB & 87.0 & 45.94% \\
# /call_genotype & int8 & 914.22 MiB & 370.0 & 21.70% \\
# /call_RGQ & int16 & 729.57 MiB & 460.0 & 17.32% \\
# /call_genotype_mask & bool & 606.02 MiB & 550.0 & 14.39% \\
# /call_genotype_phased & bool & 17.17 MiB & 9700.0 & 0.41% \\
# /variant_allele & object & 4.74 MiB & 110.0 & 0.11% \\
# /variant_filter & bool & 2.87 MiB & 0.9 & 0.07% \\
# /variant_AN & int32 & 908.75 KiB & 3.1 & 0.02% \\
# /variant_position & int32 & 810.77 KiB & 3.4 & 0.02% \\
# /sample_id & object & 357.15 KiB & 5.4 & 0.01% \\
# /variant_length & int16 & 152.4 KiB & 9.2 & 0.00% \\
# /variant_id & object & 56.18 KiB & 99.0 & 0.00% \\
# /variant_quality & float32 & 51.92 KiB & 54.0 & 0.00% \\
# /variant_id_mask & bool & 51.89 KiB & 13.0 & 0.00% \\
# /variant_contig & int16 & 50.6 KiB & 28.0 & 0.00% \\
# /region_index & int32 & 13.93 KiB & 1.2 & 0.00% \\
# /contig_length & int64 & 9.24 KiB & 2.8 & 0.00% \\
# /contig_id & object & 8.33 KiB & 3.2 & 0.00% \\
# /filter_id & object & 4.48 KiB & 0.0 & 0.00% \\
# \bottomrule
# \end{tabular}
