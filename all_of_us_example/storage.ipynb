# %%
import os
import pandas as pd
import humanfriendly
import numpy as np
from pathlib import Path

# %%
def parse_size(values):
    size = np.zeros(values.shape, dtype=int)
    for j, val in enumerate(values):
        size[j] = humanfriendly.parse_size(val)
    return size

# %%
fn = "zarr_inspect2.csv"
df_zarr = pd.read_csv(fn)
df_zarr["stored_bytes"] = parse_size(df_zarr.stored.values)
df_zarr.sort_values("stored_bytes", ascending=False, inplace=True)
df_zarr
# Out:
#                          name    dtype      stored        size     ratio  \
# 0                   /call_LAD    int16    2.26 GiB  653.86 GiB   290.000
# 1                    /call_GQ     int8    1.89 GiB  163.47 GiB    87.000
# 2                    /call_LA     int8    1.24 GiB  326.93 GiB   260.000
# 3              /call_genotype     int8  914.22 MiB  326.93 GiB   370.000
# 4                   /call_RGQ    int16  729.57 MiB  326.93 GiB   460.000
# 5         /call_genotype_mask     bool  606.02 MiB  326.93 GiB   550.000
# 6                    /call_FT   object  498.61 MiB    1.28 TiB  2700.000
# 7       /call_genotype_phased     bool   17.17 MiB  163.47 GiB  9700.000
# 8                 /variant_AF  float32    5.95 MiB  256.48 MiB    43.000
# 9   /variant_homozygote_count    int32    4.78 MiB  259.21 MiB    54.000
# 10            /variant_allele   object    4.74 MiB  518.41 MiB   110.000
# 11                /variant_AC    int32    4.24 MiB  256.48 MiB    61.000
# 12            /variant_filter     bool    2.87 MiB    2.73 MiB     0.950
# 13                /variant_AN    int32  904.75 KiB    2.73 MiB     3.100
# 14          /variant_position    int32  806.77 KiB    2.73 MiB     3.500
# 15                 /sample_id   object  357.15 KiB    1.87 MiB     5.400
# 16            /variant_length    int16   148.4 KiB    1.36 MiB     9.400
# 17                /variant_id   object   52.18 KiB    5.46 MiB   110.000
# 18           /variant_quality  float32   47.92 KiB    2.73 MiB    58.000
# 19           /variant_id_mask     bool   47.89 KiB  698.49 KiB    15.000
# 20            /variant_contig    int16    46.6 KiB    1.36 MiB    30.000
# 21              /region_index    int32   13.93 KiB   16.78 KiB     1.200
# 22             /contig_length    int64    9.24 KiB    26.3 KiB     2.800
# 23                 /contig_id   object    8.33 KiB    26.3 KiB     3.200
# 24                 /filter_id   object    4.48 KiB    32 bytes     0.007
#
#     nchunks               chunk_size avg_chunk_stored                shape  \
# 0     17900                37.41 MiB       132.17 KiB  (715256, 245394, 2)
# 1     17900                 9.35 MiB       110.55 KiB     (715256, 245394)
# 2     17900                 18.7 MiB        72.64 KiB  (715256, 245394, 2)
# 3     17900                 18.7 MiB         52.3 KiB  (715256, 245394, 2)
# 4     17900                 18.7 MiB        41.74 KiB     (715256, 245394)
# 5     17900                 18.7 MiB        34.67 KiB  (715256, 245394, 2)
# 6     17900                74.81 MiB        28.52 KiB     (715256, 245394)
# 7     17900                 9.35 MiB       1005 bytes     (715256, 245394)
# 8       716               366.81 KiB         8.51 KiB         (715256, 94)
# 9       716               370.71 KiB         6.83 KiB         (715256, 95)
# 10      716               741.42 KiB         6.78 KiB         (715256, 95)
# 11      716               366.81 KiB         6.06 KiB         (715256, 94)
# 12      716                  3.9 KiB          4.1 KiB          (715256, 4)
# 13      716                  3.9 KiB         1.26 KiB            (715256,)
# 14      716                  3.9 KiB         1.13 KiB            (715256,)
# 15       25                76.69 KiB        14.29 KiB            (245394,)
# 16      716                 1.95 KiB        212 bytes            (715256,)
# 17      716                  7.8 KiB         74 bytes            (715256,)
# 18      716                  3.9 KiB         68 bytes            (715256,)
# 19      716  998.9608938547486 bytes         68 bytes            (715256,)
# 20      716                 1.95 KiB         66 bytes            (715256,)
# 21        1                16.78 KiB        13.93 KiB             (716, 6)
# 22        1                 26.3 KiB         9.24 KiB              (3366,)
# 23        1                 26.3 KiB         8.33 KiB              (3366,)
# 24        1               32.0 bytes         4.48 KiB                 (4,)
#
#          chunk_shape                                         compressor  \
# 0   (1000, 10000, 2)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 1      (1000, 10000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 2   (1000, 10000, 2)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 3   (1000, 10000, 2)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 4      (1000, 10000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 5   (1000, 10000, 2)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 6      (1000, 10000)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 7      (1000, 10000)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 8         (1000, 94)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 9         (1000, 95)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 10        (1000, 95)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 11        (1000, 94)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 12         (1000, 4)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 13           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 14           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 15          (10000,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
# 16           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 17           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 18           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 19           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=BITSHUFF...
# 20           (1000,)  Blosc(cname='zstd', clevel=7, shuffle=NOSHUFFL...
# 21          (716, 6)  Blosc(cname='zstd', clevel=9, shuffle=NOSHUFFL...
# 22           (3366,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
# 23           (3366,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
# 24              (4,)  Blosc(cname='zstd', clevel=7, shuffle=SHUFFLE,...
#
#          filters  stored_bytes
# 0            NaN    2426656522
# 1            NaN    2029372047
# 2            NaN    1331439861
# 3            NaN     958629150
# 4            NaN     765009592
# 5            NaN     635458027
# 6   [VLenUTF8()]     522830479
# 7            NaN      18004049
# 8            NaN       6239027
# 9            NaN       5012193
# 10  [VLenUTF8()]       4970250
# 11           NaN       4445962
# 12           NaN       3009413
# 13           NaN        926464
# 14           NaN        826132
# 15  [VLenUTF8()]        365721
# 16           NaN        151961
# 17  [VLenUTF8()]         53432
# 18           NaN         49070
# 19           NaN         49039
# 20           NaN         47718
# 21           NaN         14264
# 22           NaN          9461
# 23  [VLenUTF8()]          8529
# 24  [VLenUTF8()]          4587

# %%
total = df_zarr.stored_bytes.sum()

humanfriendly.format_size(total, binary=True)
# Out:
# '8.12 GiB'

# %%
df_zarr.nchunks.sum()
# Out:
# 151821

# %%
df_display_table = pd.DataFrame({
    "Field":df_zarr.name,
    "type": df_zarr.dtype,
    "storage":df_zarr.stored,
    "compress": df_zarr.ratio,
    "percentage": df_zarr.stored_bytes / total})
threshold = 0.01 / 100 # 0.01% 
df_display_table = df_display_table[df_display_table.percentage >= threshold].copy()
df_display_table.sort_values("percentage", ascending=False, inplace=True)
df_display_table["percentage"] = df_display_table["percentage"].map('{:.2%}'.format)
df_display_table["compress"] = df_display_table["compress"].map('{:.1f}'.format)
df_display_table
# Out:
#                         Field     type     storage compress percentage
# 0                   /call_LAD    int16    2.26 GiB    290.0     27.85%
# 1                    /call_GQ     int8    1.89 GiB     87.0     23.29%
# 2                    /call_LA     int8    1.24 GiB    260.0     15.28%
# 3              /call_genotype     int8  914.22 MiB    370.0     11.00%
# 4                   /call_RGQ    int16  729.57 MiB    460.0      8.78%
# 5         /call_genotype_mask     bool  606.02 MiB    550.0      7.29%
# 6                    /call_FT   object  498.61 MiB   2700.0      6.00%
# 7       /call_genotype_phased     bool   17.17 MiB   9700.0      0.21%
# 8                 /variant_AF  float32    5.95 MiB     43.0      0.07%
# 9   /variant_homozygote_count    int32    4.78 MiB     54.0      0.06%
# 10            /variant_allele   object    4.74 MiB    110.0      0.06%
# 11                /variant_AC    int32    4.24 MiB     61.0      0.05%
# 12            /variant_filter     bool    2.87 MiB      0.9      0.03%
# 13                /variant_AN    int32  904.75 KiB      3.1      0.01%

# %%
print(df_display_table.to_latex(index=False, escape=True).replace("object", "str"))
# Out:
# \begin{tabular}{lllll}
# \toprule
# Field & type & storage & compress & percentage \\
# \midrule
# /call\_LAD & int16 & 2.26 GiB & 290.0 & 27.85\% \\
# /call\_GQ & int8 & 1.89 GiB & 87.0 & 23.29\% \\
# /call\_LA & int8 & 1.24 GiB & 260.0 & 15.28\% \\
# /call\_genotype & int8 & 914.22 MiB & 370.0 & 11.00\% \\
# /call\_RGQ & int16 & 729.57 MiB & 460.0 & 8.78\% \\
# /call\_genotype\_mask & bool & 606.02 MiB & 550.0 & 7.29\% \\
# /call\_FT & str & 498.61 MiB & 2700.0 & 6.00\% \\
# /call\_genotype\_phased & bool & 17.17 MiB & 9700.0 & 0.21\% \\
# /variant\_AF & float32 & 5.95 MiB & 43.0 & 0.07\% \\
# /variant\_homozygote\_count & int32 & 4.78 MiB & 54.0 & 0.06\% \\
# /variant\_allele & str & 4.74 MiB & 110.0 & 0.06\% \\
# /variant\_AC & int32 & 4.24 MiB & 61.0 & 0.05\% \\
# /variant\_filter & bool & 2.87 MiB & 0.9 & 0.03\% \\
# /variant\_AN & int32 & 904.75 KiB & 3.1 & 0.01\% \\
# \bottomrule
# \end{tabular}
